# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\users\utpala\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium) (0.0.6)

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Requirement already satisfied: gymnasium[toy-text] in c:\users\utpala\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium[toy-text]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium[toy-text]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium[toy-text]) (0.0.6)
# Requirement already satisfied: pygame-ce>=2.1.3 in c:\users\utpala\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.5.8)

# %%
import gymnasium as gym
import numpy as np
import random

# %%
Q = np.zeros((48,4))

# %%
epsilon = 0.1
alpha = 0.5
gamma = 0.99
episodes = 500

# %%
def epsilon_greedy(state):
    if random.random()< epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(Q[state])

# %%
for episode in range(episodes):
    env = gym.make("CliffWalking-v1")
    state,_ = env.reset()
    done = False
    action = epsilon_greedy(state)
    tot_reward=0
    episode_len=0
    while not done:
        next_state, reward, terminated, truncated,_ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        #SARSA update
        Q[state, action] += alpha * (reward + gamma*Q[next_state,next_action] - Q[state, action])

        state = next_state
        action = next_action
        tot_reward+= reward
        episode_len+=1

    print(f"Episode {episode+1}/500 : Total reward = {tot_reward} & Episode length = {episode_len}")
    env.close()
# Out:
# Episode 1/500 : Total reward = -101 & Episode length = 101
# Episode 2/500 : Total reward = -2010 & Episode length = 525
# Episode 3/500 : Total reward = -70 & Episode length = 70
# Episode 4/500 : Total reward = -102 & Episode length = 102
# Episode 5/500 : Total reward = -70 & Episode length = 70
# Episode 6/500 : Total reward = -48 & Episode length = 48
# Episode 7/500 : Total reward = -200 & Episode length = 101
# Episode 8/500 : Total reward = -178 & Episode length = 79
# Episode 9/500 : Total reward = -58 & Episode length = 58
# Episode 10/500 : Total reward = -191 & Episode length = 92
# Episode 11/500 : Total reward = -158 & Episode length = 59
# Episode 12/500 : Total reward = -48 & Episode length = 48
# Episode 13/500 : Total reward = -65 & Episode length = 65
# Episode 14/500 : Total reward = -45 & Episode length = 45
# Episode 15/500 : Total reward = -192 & Episode length = 93
# Episode 16/500 : Total reward = -39 & Episode length = 39
# Episode 17/500 : Total reward = -32 & Episode length = 32
# Episode 18/500 : Total reward = -41 & Episode length = 41
# Episode 19/500 : Total reward = -179 & Episode length = 80
# Episode 20/500 : Total reward = -50 & Episode length = 50
# Episode 21/500 : Total reward = -45 & Episode length = 45
# Episode 22/500 : Total reward = -39 & Episode length = 39
# Episode 23/500 : Total reward = -33 & Episode length = 33
# Episode 24/500 : Total reward = -44 & Episode length = 44
# Episode 25/500 : Total reward = -31 & Episode length = 31
# Episode 26/500 : Total reward = -124 & Episode length = 25
# Episode 27/500 : Total reward = -342 & Episode length = 45
# Episode 28/500 : Total reward = -29 & Episode length = 29
# Episode 29/500 : Total reward = -50 & Episode length = 50
# Episode 30/500 : Total reward = -29 & Episode length = 29
# Episode 31/500 : Total reward = -28 & Episode length = 28
# Episode 32/500 : Total reward = -25 & Episode length = 25
# Episode 33/500 : Total reward = -23 & Episode length = 23
# Episode 34/500 : Total reward = -45 & Episode length = 45
# Episode 35/500 : Total reward = -27 & Episode length = 27
# Episode 36/500 : Total reward = -23 & Episode length = 23
# Episode 37/500 : Total reward = -28 & Episode length = 28
# Episode 38/500 : Total reward = -31 & Episode length = 31
# Episode 39/500 : Total reward = -149 & Episode length = 50
# Episode 40/500 : Total reward = -25 & Episode length = 25
# Episode 41/500 : Total reward = -34 & Episode length = 34
# Episode 42/500 : Total reward = -23 & Episode length = 23
# Episode 43/500 : Total reward = -22 & Episode length = 22
# Episode 44/500 : Total reward = -33 & Episode length = 33
# Episode 45/500 : Total reward = -223 & Episode length = 124
# Episode 46/500 : Total reward = -20 & Episode length = 20
# Episode 47/500 : Total reward = -27 & Episode length = 27
# Episode 48/500 : Total reward = -23 & Episode length = 23
# Episode 49/500 : Total reward = -27 & Episode length = 27
# Episode 50/500 : Total reward = -24 & Episode length = 24
# Episode 51/500 : Total reward = -21 & Episode length = 21
# Episode 52/500 : Total reward = -21 & Episode length = 21
# Episode 53/500 : Total reward = -19 & Episode length = 19
# Episode 54/500 : Total reward = -19 & Episode length = 19
# Episode 55/500 : Total reward = -17 & Episode length = 17
# Episode 56/500 : Total reward = -17 & Episode length = 17
# Episode 57/500 : Total reward = -25 & Episode length = 25
# Episode 58/500 : Total reward = -234 & Episode length = 36
# Episode 59/500 : Total reward = -19 & Episode length = 19
# Episode 60/500 : Total reward = -24 & Episode length = 24
# Episode 61/500 : Total reward = -30 & Episode length = 30
# Episode 62/500 : Total reward = -23 & Episode length = 23
# Episode 63/500 : Total reward = -131 & Episode length = 32
# Episode 64/500 : Total reward = -19 & Episode length = 19
# Episode 65/500 : Total reward = -21 & Episode length = 21
# Episode 66/500 : Total reward = -23 & Episode length = 23
# Episode 67/500 : Total reward = -20 & Episode length = 20
# Episode 68/500 : Total reward = -19 & Episode length = 19
# Episode 69/500 : Total reward = -28 & Episode length = 28
# Episode 70/500 : Total reward = -29 & Episode length = 29
# Episode 71/500 : Total reward = -17 & Episode length = 17
# Episode 72/500 : Total reward = -26 & Episode length = 26
# Episode 73/500 : Total reward = -21 & Episode length = 21
# Episode 74/500 : Total reward = -23 & Episode length = 23
# Episode 75/500 : Total reward = -19 & Episode length = 19
# Episode 76/500 : Total reward = -20 & Episode length = 20
# Episode 77/500 : Total reward = -18 & Episode length = 18
# Episode 78/500 : Total reward = -21 & Episode length = 21
# Episode 79/500 : Total reward = -18 & Episode length = 18
# Episode 80/500 : Total reward = -23 & Episode length = 23
# Episode 81/500 : Total reward = -20 & Episode length = 20
# Episode 82/500 : Total reward = -21 & Episode length = 21
# Episode 83/500 : Total reward = -21 & Episode length = 21
# Episode 84/500 : Total reward = -19 & Episode length = 19
# Episode 85/500 : Total reward = -17 & Episode length = 17
# Episode 86/500 : Total reward = -126 & Episode length = 27
# Episode 87/500 : Total reward = -28 & Episode length = 28
# Episode 88/500 : Total reward = -17 & Episode length = 17
# Episode 89/500 : Total reward = -19 & Episode length = 19
# Episode 90/500 : Total reward = -21 & Episode length = 21
# Episode 91/500 : Total reward = -23 & Episode length = 23
# Episode 92/500 : Total reward = -23 & Episode length = 23
# Episode 93/500 : Total reward = -24 & Episode length = 24
# Episode 94/500 : Total reward = -138 & Episode length = 39
# Episode 95/500 : Total reward = -17 & Episode length = 17
# Episode 96/500 : Total reward = -19 & Episode length = 19
# Episode 97/500 : Total reward = -17 & Episode length = 17
# Episode 98/500 : Total reward = -17 & Episode length = 17
# Episode 99/500 : Total reward = -119 & Episode length = 20
# Episode 100/500 : Total reward = -20 & Episode length = 20
# Episode 101/500 : Total reward = -25 & Episode length = 25
# Episode 102/500 : Total reward = -17 & Episode length = 17
# Episode 103/500 : Total reward = -25 & Episode length = 25
# Episode 104/500 : Total reward = -17 & Episode length = 17
# Episode 105/500 : Total reward = -18 & Episode length = 18
# Episode 106/500 : Total reward = -119 & Episode length = 20
# Episode 107/500 : Total reward = -19 & Episode length = 19
# Episode 108/500 : Total reward = -19 & Episode length = 19
# Episode 109/500 : Total reward = -22 & Episode length = 22
# Episode 110/500 : Total reward = -25 & Episode length = 25
# Episode 111/500 : Total reward = -17 & Episode length = 17
# Episode 112/500 : Total reward = -23 & Episode length = 23
# Episode 113/500 : Total reward = -27 & Episode length = 27
# Episode 114/500 : Total reward = -19 & Episode length = 19
# Episode 115/500 : Total reward = -26 & Episode length = 26
# Episode 116/500 : Total reward = -20 & Episode length = 20
# Episode 117/500 : Total reward = -25 & Episode length = 25
# Episode 118/500 : Total reward = -17 & Episode length = 17
# Episode 119/500 : Total reward = -17 & Episode length = 17
# Episode 120/500 : Total reward = -21 & Episode length = 21
# Episode 121/500 : Total reward = -19 & Episode length = 19
# Episode 122/500 : Total reward = -123 & Episode length = 24
# Episode 123/500 : Total reward = -21 & Episode length = 21
# Episode 124/500 : Total reward = -118 & Episode length = 19
# Episode 125/500 : Total reward = -23 & Episode length = 23
# Episode 126/500 : Total reward = -21 & Episode length = 21
# Episode 127/500 : Total reward = -19 & Episode length = 19
# Episode 128/500 : Total reward = -24 & Episode length = 24
# Episode 129/500 : Total reward = -19 & Episode length = 19
# Episode 130/500 : Total reward = -19 & Episode length = 19
# Episode 131/500 : Total reward = -17 & Episode length = 17
# Episode 132/500 : Total reward = -19 & Episode length = 19
# Episode 133/500 : Total reward = -26 & Episode length = 26
# Episode 134/500 : Total reward = -134 & Episode length = 35
# Episode 135/500 : Total reward = -17 & Episode length = 17
# Episode 136/500 : Total reward = -18 & Episode length = 18
# Episode 137/500 : Total reward = -32 & Episode length = 32
# Episode 138/500 : Total reward = -22 & Episode length = 22
# Episode 139/500 : Total reward = -21 & Episode length = 21
# Episode 140/500 : Total reward = -25 & Episode length = 25
# Episode 141/500 : Total reward = -23 & Episode length = 23
# Episode 142/500 : Total reward = -278 & Episode length = 278
# Episode 143/500 : Total reward = -25 & Episode length = 25
# Episode 144/500 : Total reward = -20 & Episode length = 20
# Episode 145/500 : Total reward = -19 & Episode length = 19
# Episode 146/500 : Total reward = -35 & Episode length = 35
# Episode 147/500 : Total reward = -20 & Episode length = 20
# Episode 148/500 : Total reward = -17 & Episode length = 17
# Episode 149/500 : Total reward = -19 & Episode length = 19
# Episode 150/500 : Total reward = -17 & Episode length = 17
# Episode 151/500 : Total reward = -17 & Episode length = 17
# Episode 152/500 : Total reward = -18 & Episode length = 18
# Episode 153/500 : Total reward = -17 & Episode length = 17
# Episode 154/500 : Total reward = -24 & Episode length = 24
# Episode 155/500 : Total reward = -26 & Episode length = 26
# Episode 156/500 : Total reward = -19 & Episode length = 19
# Episode 157/500 : Total reward = -18 & Episode length = 18
# Episode 158/500 : Total reward = -25 & Episode length = 25
# Episode 159/500 : Total reward = -17 & Episode length = 17
# Episode 160/500 : Total reward = -121 & Episode length = 22
# Episode 161/500 : Total reward = -17 & Episode length = 17
# Episode 162/500 : Total reward = -18 & Episode length = 18
# Episode 163/500 : Total reward = -19 & Episode length = 19
# Episode 164/500 : Total reward = -23 & Episode length = 23
# Episode 165/500 : Total reward = -20 & Episode length = 20
# Episode 166/500 : Total reward = -25 & Episode length = 25
# Episode 167/500 : Total reward = -17 & Episode length = 17
# Episode 168/500 : Total reward = -17 & Episode length = 17
# Episode 169/500 : Total reward = -25 & Episode length = 25
# Episode 170/500 : Total reward = -24 & Episode length = 24
# Episode 171/500 : Total reward = -25 & Episode length = 25
# Episode 172/500 : Total reward = -21 & Episode length = 21
# Episode 173/500 : Total reward = -17 & Episode length = 17
# Episode 174/500 : Total reward = -17 & Episode length = 17
# Episode 175/500 : Total reward = -24 & Episode length = 24
# Episode 176/500 : Total reward = -29 & Episode length = 29
# Episode 177/500 : Total reward = -23 & Episode length = 23
# Episode 178/500 : Total reward = -23 & Episode length = 23
# Episode 179/500 : Total reward = -29 & Episode length = 29
# Episode 180/500 : Total reward = -67 & Episode length = 67
# Episode 181/500 : Total reward = -21 & Episode length = 21
# Episode 182/500 : Total reward = -31 & Episode length = 31
# Episode 183/500 : Total reward = -18 & Episode length = 18
# Episode 184/500 : Total reward = -29 & Episode length = 29
# Episode 185/500 : Total reward = -230 & Episode length = 32
# Episode 186/500 : Total reward = -21 & Episode length = 21
# Episode 187/500 : Total reward = -17 & Episode length = 17
# Episode 188/500 : Total reward = -20 & Episode length = 20
# Episode 189/500 : Total reward = -18 & Episode length = 18
# Episode 190/500 : Total reward = -17 & Episode length = 17
# Episode 191/500 : Total reward = -24 & Episode length = 24
# Episode 192/500 : Total reward = -22 & Episode length = 22
# Episode 193/500 : Total reward = -17 & Episode length = 17
# Episode 194/500 : Total reward = -17 & Episode length = 17
# Episode 195/500 : Total reward = -19 & Episode length = 19
# Episode 196/500 : Total reward = -25 & Episode length = 25
# Episode 197/500 : Total reward = -20 & Episode length = 20
# Episode 198/500 : Total reward = -248 & Episode length = 50
# Episode 199/500 : Total reward = -29 & Episode length = 29
# Episode 200/500 : Total reward = -23 & Episode length = 23
# Episode 201/500 : Total reward = -27 & Episode length = 27
# Episode 202/500 : Total reward = -21 & Episode length = 21
# Episode 203/500 : Total reward = -23 & Episode length = 23
# Episode 204/500 : Total reward = -17 & Episode length = 17
# Episode 205/500 : Total reward = -19 & Episode length = 19
# Episode 206/500 : Total reward = -22 & Episode length = 22
# Episode 207/500 : Total reward = -17 & Episode length = 17
# Episode 208/500 : Total reward = -17 & Episode length = 17
# Episode 209/500 : Total reward = -20 & Episode length = 20
# Episode 210/500 : Total reward = -18 & Episode length = 18
# Episode 211/500 : Total reward = -17 & Episode length = 17
# Episode 212/500 : Total reward = -30 & Episode length = 30
# Episode 213/500 : Total reward = -17 & Episode length = 17
# Episode 214/500 : Total reward = -17 & Episode length = 17
# Episode 215/500 : Total reward = -21 & Episode length = 21
# Episode 216/500 : Total reward = -19 & Episode length = 19
# Episode 217/500 : Total reward = -119 & Episode length = 20
# Episode 218/500 : Total reward = -27 & Episode length = 27
# Episode 219/500 : Total reward = -49 & Episode length = 49
# Episode 220/500 : Total reward = -17 & Episode length = 17
# Episode 221/500 : Total reward = -18 & Episode length = 18
# Episode 222/500 : Total reward = -19 & Episode length = 19
# Episode 223/500 : Total reward = -20 & Episode length = 20
# Episode 224/500 : Total reward = -24 & Episode length = 24
# Episode 225/500 : Total reward = -21 & Episode length = 21
# Episode 226/500 : Total reward = -19 & Episode length = 19
# Episode 227/500 : Total reward = -19 & Episode length = 19
# Episode 228/500 : Total reward = -18 & Episode length = 18
# Episode 229/500 : Total reward = -17 & Episode length = 17
# Episode 230/500 : Total reward = -18 & Episode length = 18
# Episode 231/500 : Total reward = -17 & Episode length = 17
# Episode 232/500 : Total reward = -21 & Episode length = 21
# Episode 233/500 : Total reward = -19 & Episode length = 19
# Episode 234/500 : Total reward = -18 & Episode length = 18
# Episode 235/500 : Total reward = -19 & Episode length = 19
# Episode 236/500 : Total reward = -23 & Episode length = 23
# Episode 237/500 : Total reward = -23 & Episode length = 23
# Episode 238/500 : Total reward = -117 & Episode length = 18
# Episode 239/500 : Total reward = -17 & Episode length = 17
# Episode 240/500 : Total reward = -19 & Episode length = 19
# Episode 241/500 : Total reward = -19 & Episode length = 19
# Episode 242/500 : Total reward = -21 & Episode length = 21
# Episode 243/500 : Total reward = -17 & Episode length = 17
# Episode 244/500 : Total reward = -17 & Episode length = 17
# Episode 245/500 : Total reward = -19 & Episode length = 19
# Episode 246/500 : Total reward = -21 & Episode length = 21
# Episode 247/500 : Total reward = -20 & Episode length = 20
# Episode 248/500 : Total reward = -24 & Episode length = 24
# Episode 249/500 : Total reward = -21 & Episode length = 21
# Episode 250/500 : Total reward = -17 & Episode length = 17
# Episode 251/500 : Total reward = -23 & Episode length = 23
# Episode 252/500 : Total reward = -25 & Episode length = 25
# Episode 253/500 : Total reward = -17 & Episode length = 17
# Episode 254/500 : Total reward = -18 & Episode length = 18
# Episode 255/500 : Total reward = -17 & Episode length = 17
# Episode 256/500 : Total reward = -19 & Episode length = 19
# Episode 257/500 : Total reward = -23 & Episode length = 23
# Episode 258/500 : Total reward = -21 & Episode length = 21
# Episode 259/500 : Total reward = -135 & Episode length = 36
# Episode 260/500 : Total reward = -17 & Episode length = 17
# Episode 261/500 : Total reward = -24 & Episode length = 24
# Episode 262/500 : Total reward = -17 & Episode length = 17
# Episode 263/500 : Total reward = -17 & Episode length = 17
# Episode 264/500 : Total reward = -17 & Episode length = 17
# Episode 265/500 : Total reward = -17 & Episode length = 17
# Episode 266/500 : Total reward = -25 & Episode length = 25
# Episode 267/500 : Total reward = -22 & Episode length = 22
# Episode 268/500 : Total reward = -30 & Episode length = 30
# Episode 269/500 : Total reward = -19 & Episode length = 19
# Episode 270/500 : Total reward = -122 & Episode length = 23
# Episode 271/500 : Total reward = -23 & Episode length = 23
# Episode 272/500 : Total reward = -19 & Episode length = 19
# Episode 273/500 : Total reward = -19 & Episode length = 19
# Episode 274/500 : Total reward = -17 & Episode length = 17
# Episode 275/500 : Total reward = -20 & Episode length = 20
# Episode 276/500 : Total reward = -18 & Episode length = 18
# Episode 277/500 : Total reward = -17 & Episode length = 17
# Episode 278/500 : Total reward = -18 & Episode length = 18
# Episode 279/500 : Total reward = -20 & Episode length = 20
# Episode 280/500 : Total reward = -20 & Episode length = 20
# Episode 281/500 : Total reward = -20 & Episode length = 20
# Episode 282/500 : Total reward = -19 & Episode length = 19
# Episode 283/500 : Total reward = -20 & Episode length = 20
# Episode 284/500 : Total reward = -18 & Episode length = 18
# Episode 285/500 : Total reward = -20 & Episode length = 20
# Episode 286/500 : Total reward = -20 & Episode length = 20
# Episode 287/500 : Total reward = -17 & Episode length = 17
# Episode 288/500 : Total reward = -19 & Episode length = 19
# Episode 289/500 : Total reward = -25 & Episode length = 25
# Episode 290/500 : Total reward = -23 & Episode length = 23
# Episode 291/500 : Total reward = -32 & Episode length = 32
# Episode 292/500 : Total reward = -22 & Episode length = 22
# Episode 293/500 : Total reward = -21 & Episode length = 21
# Episode 294/500 : Total reward = -18 & Episode length = 18
# Episode 295/500 : Total reward = -21 & Episode length = 21
# Episode 296/500 : Total reward = -137 & Episode length = 38
# Episode 297/500 : Total reward = -23 & Episode length = 23
# Episode 298/500 : Total reward = -17 & Episode length = 17
# Episode 299/500 : Total reward = -20 & Episode length = 20
# Episode 300/500 : Total reward = -19 & Episode length = 19
# Episode 301/500 : Total reward = -17 & Episode length = 17
# Episode 302/500 : Total reward = -23 & Episode length = 23
# Episode 303/500 : Total reward = -17 & Episode length = 17
# Episode 304/500 : Total reward = -21 & Episode length = 21
# Episode 305/500 : Total reward = -17 & Episode length = 17
# Episode 306/500 : Total reward = -24 & Episode length = 24
# Episode 307/500 : Total reward = -20 & Episode length = 20
# Episode 308/500 : Total reward = -17 & Episode length = 17
# Episode 309/500 : Total reward = -17 & Episode length = 17
# Episode 310/500 : Total reward = -22 & Episode length = 22
# Episode 311/500 : Total reward = -17 & Episode length = 17
# Episode 312/500 : Total reward = -17 & Episode length = 17
# Episode 313/500 : Total reward = -17 & Episode length = 17
# Episode 314/500 : Total reward = -18 & Episode length = 18
# Episode 315/500 : Total reward = -20 & Episode length = 20
# Episode 316/500 : Total reward = -32 & Episode length = 32
# Episode 317/500 : Total reward = -19 & Episode length = 19
# Episode 318/500 : Total reward = -116 & Episode length = 116
# Episode 319/500 : Total reward = -27 & Episode length = 27
# Episode 320/500 : Total reward = -27 & Episode length = 27
# Episode 321/500 : Total reward = -19 & Episode length = 19
# Episode 322/500 : Total reward = -27 & Episode length = 27
# Episode 323/500 : Total reward = -139 & Episode length = 40
# Episode 324/500 : Total reward = -25 & Episode length = 25
# Episode 325/500 : Total reward = -1012 & Episode length = 814
# Episode 326/500 : Total reward = -27 & Episode length = 27
# Episode 327/500 : Total reward = -96 & Episode length = 96
# Episode 328/500 : Total reward = -701 & Episode length = 602
# Episode 329/500 : Total reward = -127 & Episode length = 127
# Episode 330/500 : Total reward = -78 & Episode length = 78
# Episode 331/500 : Total reward = -279 & Episode length = 180
# Episode 332/500 : Total reward = -190 & Episode length = 190
# Episode 333/500 : Total reward = -159 & Episode length = 159
# Episode 334/500 : Total reward = -59 & Episode length = 59
# Episode 335/500 : Total reward = -49 & Episode length = 49
# Episode 336/500 : Total reward = -26 & Episode length = 26
# Episode 337/500 : Total reward = -181 & Episode length = 82
# Episode 338/500 : Total reward = -19 & Episode length = 19
# Episode 339/500 : Total reward = -37 & Episode length = 37
# Episode 340/500 : Total reward = -70 & Episode length = 70
# Episode 341/500 : Total reward = -33 & Episode length = 33
# Episode 342/500 : Total reward = -55 & Episode length = 55
# Episode 343/500 : Total reward = -19 & Episode length = 19
# Episode 344/500 : Total reward = -28 & Episode length = 28
# Episode 345/500 : Total reward = -32 & Episode length = 32
# Episode 346/500 : Total reward = -17 & Episode length = 17
# Episode 347/500 : Total reward = -25 & Episode length = 25
# Episode 348/500 : Total reward = -24 & Episode length = 24
# Episode 349/500 : Total reward = -17 & Episode length = 17
# Episode 350/500 : Total reward = -19 & Episode length = 19
# Episode 351/500 : Total reward = -19 & Episode length = 19
# Episode 352/500 : Total reward = -20 & Episode length = 20
# Episode 353/500 : Total reward = -17 & Episode length = 17
# Episode 354/500 : Total reward = -19 & Episode length = 19
# Episode 355/500 : Total reward = -17 & Episode length = 17
# Episode 356/500 : Total reward = -19 & Episode length = 19
# Episode 357/500 : Total reward = -18 & Episode length = 18
# Episode 358/500 : Total reward = -21 & Episode length = 21
# Episode 359/500 : Total reward = -19 & Episode length = 19
# Episode 360/500 : Total reward = -19 & Episode length = 19
# Episode 361/500 : Total reward = -20 & Episode length = 20
# Episode 362/500 : Total reward = -122 & Episode length = 23
# Episode 363/500 : Total reward = -17 & Episode length = 17
# Episode 364/500 : Total reward = -19 & Episode length = 19
# Episode 365/500 : Total reward = -21 & Episode length = 21
# Episode 366/500 : Total reward = -20 & Episode length = 20
# Episode 367/500 : Total reward = -22 & Episode length = 22
# Episode 368/500 : Total reward = -18 & Episode length = 18
# Episode 369/500 : Total reward = -17 & Episode length = 17
# Episode 370/500 : Total reward = -18 & Episode length = 18
# Episode 371/500 : Total reward = -17 & Episode length = 17
# Episode 372/500 : Total reward = -19 & Episode length = 19
# Episode 373/500 : Total reward = -22 & Episode length = 22
# Episode 374/500 : Total reward = -25 & Episode length = 25
# Episode 375/500 : Total reward = -17 & Episode length = 17
# Episode 376/500 : Total reward = -18 & Episode length = 18
# Episode 377/500 : Total reward = -19 & Episode length = 19
# Episode 378/500 : Total reward = -27 & Episode length = 27
# Episode 379/500 : Total reward = -240 & Episode length = 42
# Episode 380/500 : Total reward = -25 & Episode length = 25
# Episode 381/500 : Total reward = -147 & Episode length = 48
# Episode 382/500 : Total reward = -18 & Episode length = 18
# Episode 383/500 : Total reward = -17 & Episode length = 17
# Episode 384/500 : Total reward = -17 & Episode length = 17
# Episode 385/500 : Total reward = -154 & Episode length = 55
# Episode 386/500 : Total reward = -17 & Episode length = 17
# Episode 387/500 : Total reward = -118 & Episode length = 19
# Episode 388/500 : Total reward = -17 & Episode length = 17
# Episode 389/500 : Total reward = -21 & Episode length = 21
# Episode 390/500 : Total reward = -17 & Episode length = 17
# Episode 391/500 : Total reward = -18 & Episode length = 18
# Episode 392/500 : Total reward = -19 & Episode length = 19
# Episode 393/500 : Total reward = -29 & Episode length = 29
# Episode 394/500 : Total reward = -19 & Episode length = 19
# Episode 395/500 : Total reward = -22 & Episode length = 22
# Episode 396/500 : Total reward = -20 & Episode length = 20
# Episode 397/500 : Total reward = -28 & Episode length = 28
# Episode 398/500 : Total reward = -21 & Episode length = 21
# Episode 399/500 : Total reward = -86 & Episode length = 86
# Episode 400/500 : Total reward = -121 & Episode length = 22
# Episode 401/500 : Total reward = -43 & Episode length = 43
# Episode 402/500 : Total reward = -21 & Episode length = 21
# Episode 403/500 : Total reward = -23 & Episode length = 23
# Episode 404/500 : Total reward = -31 & Episode length = 31
# Episode 405/500 : Total reward = -17 & Episode length = 17
# Episode 406/500 : Total reward = -18 & Episode length = 18
# Episode 407/500 : Total reward = -22 & Episode length = 22
# Episode 408/500 : Total reward = -19 & Episode length = 19
# Episode 409/500 : Total reward = -17 & Episode length = 17
# Episode 410/500 : Total reward = -19 & Episode length = 19
# Episode 411/500 : Total reward = -18 & Episode length = 18
# Episode 412/500 : Total reward = -17 & Episode length = 17
# Episode 413/500 : Total reward = -19 & Episode length = 19
# Episode 414/500 : Total reward = -30 & Episode length = 30
# Episode 415/500 : Total reward = -17 & Episode length = 17
# Episode 416/500 : Total reward = -17 & Episode length = 17
# Episode 417/500 : Total reward = -20 & Episode length = 20
# Episode 418/500 : Total reward = -22 & Episode length = 22
# Episode 419/500 : Total reward = -22 & Episode length = 22
# Episode 420/500 : Total reward = -17 & Episode length = 17
# Episode 421/500 : Total reward = -180 & Episode length = 81
# Episode 422/500 : Total reward = -22 & Episode length = 22
# Episode 423/500 : Total reward = -145 & Episode length = 46
# Episode 424/500 : Total reward = -218 & Episode length = 218
# Episode 425/500 : Total reward = -38 & Episode length = 38
# Episode 426/500 : Total reward = -21 & Episode length = 21
# Episode 427/500 : Total reward = -182 & Episode length = 182
# Episode 428/500 : Total reward = -263 & Episode length = 164
# Episode 429/500 : Total reward = -55 & Episode length = 55
# Episode 430/500 : Total reward = -23 & Episode length = 23
# Episode 431/500 : Total reward = -36 & Episode length = 36
# Episode 432/500 : Total reward = -58 & Episode length = 58
# Episode 433/500 : Total reward = -23 & Episode length = 23
# Episode 434/500 : Total reward = -24 & Episode length = 24
# Episode 435/500 : Total reward = -19 & Episode length = 19
# Episode 436/500 : Total reward = -19 & Episode length = 19
# Episode 437/500 : Total reward = -21 & Episode length = 21
# Episode 438/500 : Total reward = -19 & Episode length = 19
# Episode 439/500 : Total reward = -19 & Episode length = 19
# Episode 440/500 : Total reward = -24 & Episode length = 24
# Episode 441/500 : Total reward = -17 & Episode length = 17
# Episode 442/500 : Total reward = -19 & Episode length = 19
# Episode 443/500 : Total reward = -20 & Episode length = 20
# Episode 444/500 : Total reward = -21 & Episode length = 21
# Episode 445/500 : Total reward = -17 & Episode length = 17
# Episode 446/500 : Total reward = -19 & Episode length = 19
# Episode 447/500 : Total reward = -17 & Episode length = 17
# Episode 448/500 : Total reward = -19 & Episode length = 19
# Episode 449/500 : Total reward = -21 & Episode length = 21
# Episode 450/500 : Total reward = -21 & Episode length = 21
# Episode 451/500 : Total reward = -17 & Episode length = 17
# Episode 452/500 : Total reward = -19 & Episode length = 19
# Episode 453/500 : Total reward = -24 & Episode length = 24
# Episode 454/500 : Total reward = -17 & Episode length = 17
# Episode 455/500 : Total reward = -17 & Episode length = 17
# Episode 456/500 : Total reward = -17 & Episode length = 17
# Episode 457/500 : Total reward = -19 & Episode length = 19
# Episode 458/500 : Total reward = -19 & Episode length = 19
# Episode 459/500 : Total reward = -19 & Episode length = 19
# Episode 460/500 : Total reward = -18 & Episode length = 18
# Episode 461/500 : Total reward = -17 & Episode length = 17
# Episode 462/500 : Total reward = -22 & Episode length = 22
# Episode 463/500 : Total reward = -19 & Episode length = 19
# Episode 464/500 : Total reward = -20 & Episode length = 20
# Episode 465/500 : Total reward = -19 & Episode length = 19
# Episode 466/500 : Total reward = -22 & Episode length = 22
# Episode 467/500 : Total reward = -21 & Episode length = 21
# Episode 468/500 : Total reward = -17 & Episode length = 17
# Episode 469/500 : Total reward = -17 & Episode length = 17
# Episode 470/500 : Total reward = -17 & Episode length = 17
# Episode 471/500 : Total reward = -20 & Episode length = 20
# Episode 472/500 : Total reward = -39 & Episode length = 39
# Episode 473/500 : Total reward = -173 & Episode length = 74
# Episode 474/500 : Total reward = -18 & Episode length = 18
# Episode 475/500 : Total reward = -22 & Episode length = 22
# Episode 476/500 : Total reward = -31 & Episode length = 31
# Episode 477/500 : Total reward = -34 & Episode length = 34
# Episode 478/500 : Total reward = -17 & Episode length = 17
# Episode 479/500 : Total reward = -45 & Episode length = 45
# Episode 480/500 : Total reward = -17 & Episode length = 17
# Episode 481/500 : Total reward = -22 & Episode length = 22
# Episode 482/500 : Total reward = -20 & Episode length = 20
# Episode 483/500 : Total reward = -19 & Episode length = 19
# Episode 484/500 : Total reward = -20 & Episode length = 20
# Episode 485/500 : Total reward = -18 & Episode length = 18
# Episode 486/500 : Total reward = -22 & Episode length = 22
# Episode 487/500 : Total reward = -19 & Episode length = 19
# Episode 488/500 : Total reward = -20 & Episode length = 20
# Episode 489/500 : Total reward = -23 & Episode length = 23
# Episode 490/500 : Total reward = -20 & Episode length = 20
# Episode 491/500 : Total reward = -19 & Episode length = 19
# Episode 492/500 : Total reward = -19 & Episode length = 19
# Episode 493/500 : Total reward = -20 & Episode length = 20
# Episode 494/500 : Total reward = -18 & Episode length = 18
# Episode 495/500 : Total reward = -18 & Episode length = 18
# Episode 496/500 : Total reward = -18 & Episode length = 18
# Episode 497/500 : Total reward = -18 & Episode length = 18
# Episode 498/500 : Total reward = -22 & Episode length = 22
# Episode 499/500 : Total reward = -17 & Episode length = 17
# Episode 500/500 : Total reward = -17 & Episode length = 17

# %%
# what did our agent learn 
env = gym.make("CliffWalking-v1", render_mode="human")
state,_=env.reset()
done = False
tot_reward = 0 
episode_len = 0
while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    tot_reward+= reward
    episode_len+=1
print(f"Total reward = {tot_reward} & Episode length = {episode_len}")
env.close()
# Out:
# Total reward = -17 & Episode length = 17
